# %%
import pandas as pd


game_sales_data = pd.read_csv('vgsales.csv', index_col=0)
game_sales_data
# Out:
#                                                    Name Platform    Year  \
# Rank
# 1                                            Wii Sports      Wii  2006.0
# 2                                     Super Mario Bros.      NES  1985.0
# 3                                        Mario Kart Wii      Wii  2008.0
# 4                                     Wii Sports Resort      Wii  2009.0
# 5                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# 1            Sports    Nintendo     41.49     29.02      3.77         8.46
# 2          Platform    Nintendo     29.08      3.58      6.81         0.77
# 3            Racing    Nintendo     15.85     12.88      3.79         3.31
# 4            Sports    Nintendo     15.75     11.01      3.28         2.96
# 5      Role-Playing    Nintendo     11.27      8.89     10.22         1.00
# ...             ...         ...       ...       ...       ...          ...
# 16596      Platform       Kemco      0.01      0.00      0.00         0.00
# 16597       Shooter  Infogrames      0.01      0.00      0.00         0.00
# 16598        Racing  Activision      0.00      0.00      0.00         0.00
# 16599        Puzzle    7G//AMES      0.00      0.01      0.00         0.00
# 16600      Platform     Wanadoo      0.01      0.00      0.00         0.00
#
#        Global_Sales
# Rank
# 1             82.74
# 2             40.24
# 3             35.82
# 4             33.00
# 5             31.37
# ...             ...
# 16596          0.01
# 16597          0.01
# 16598          0.01
# 16599          0.01
# 16600          0.01
#
# [16598 rows x 10 columns]

# %%
#Create new tables in database

from sqlalchemy import Column, Integer, String, Date, Text, VARCHAR, Float, MetaData, Table, select
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import ForeignKey
from sqlalchemy import CheckConstraint, UniqueConstraint
from sqlalchemy.orm import sessionmaker


Base = declarative_base()

from sqlalchemy import create_engine

db_string = "postgres://postgres:admin@localhost:5432/game_sales"
engine = create_engine(db_string)


class Platform(Base):
    __tablename__ = 'Platform'
    __table_args__ = (
        CheckConstraint('LENGTH(platform_name) > 0'),
        UniqueConstraint('platform_name'),
        {'extend_existing' : True},
    )
    platform_id = Column(Integer, primary_key=True)
    platform_name = Column(String(50), nullable = False)
    
    def __repr__(self):
        return "<Platform(platform_id='{0}', platform_name={1})>".format(self.platform_id, self.platform_name)
    
class Category(Base):
    __tablename__ = 'Category'
    __table_args__ = (
        CheckConstraint('LENGTH(category_name) > 0'),
        UniqueConstraint('category_name'),
        {'extend_existing' : True},
    )
    category_id = Column(Integer, primary_key=True)
    category_name = Column(String(50), nullable = False)
    
    def __repr__(self):
        return "<Category(category_id='{0}', category_name={1})>".format(self.category_id, self.category_name)

class Game(Base):
    __tablename__ = 'Game'
    
    game_id = Column(Integer, primary_key=True)
    game_name = Column(String(300), nullable = False)
    platform_id = Column(Integer, ForeignKey('Platform.platform_id'))
    year = Column(Integer)
    category_id = Column(Integer, ForeignKey('Category.category_id'))
    publisher_id = Column(Integer, ForeignKey('Publisher.publisher_id'))
    
    def __repr__(self):
        return "<Game(game_id={0}, game_name='{1}', platform_id={2}, year={3}, category_id={4}, publisher_id={5})>".format(self.game_id, self.game_name, self.platform_id, self.year, self.category.id, self.publisher_id)
    
class Publisher(Base):
    __tablename__ = 'Publisher'
    
    publisher_id = Column(Integer, primary_key=True)
    publisher_name = Column(String(50))
    
    def __repr__(self):
        return "<SuperBowl(publisher_id='{0}', publisher_name={1})>".format(self.publisher_id, self.publisher_name)
    
class Sales(Base):
    __tablename__ = 'Sales'
    
    game_id = Column(Integer, primary_key=True)
    NA_Sales = Column(Float)
    EU_Sales = Column(Float)
    JP_Sales = Column(Float)
    Other_Sales = Column(Float)
    Global_Sales = Column(Float)
    
    def __repr__(self):
        return "<Sales(game_id={0}, NA_Sales={1}, EU_Sales={2}, JP_Sales={3}, Other_Sales={4}, Global_Sales={5})>".format(self.game_id, self.NA_Sales, self.EU_Sales, self.JP_Sales, self.Other_Sales, self.Global_Sales)

    
Base.metadata.create_all(engine)

# %%
platforms_list = pd.DataFrame(columns=['platform_name'])
platforms_list['platform_name'] = game_sales_data['Platform'].unique()
platforms_list.index.name = 'platform_id'
platforms_list
# Out:
#             platform_name
# platform_id
# 0                     Wii
# 1                     NES
# 2                      GB
# 3                      DS
# 4                    X360
# 5                     PS3
# 6                     PS2
# 7                    SNES
# 8                     GBA
# 9                     3DS
# 10                    PS4
# 11                    N64
# 12                     PS
# 13                     XB
# 14                     PC
# 15                   2600
# 16                    PSP
# 17                   XOne
# 18                     GC
# 19                   WiiU
# 20                    GEN
# 21                     DC
# 22                    PSV
# 23                    SAT
# 24                    SCD
# 25                     WS
# 26                     NG
# 27                   TG16
# 28                    3DO
# 29                     GG
# 30                   PCFX

# %%
categories_list = pd.DataFrame(columns=['category_name'])
categories_list['category_name'] = game_sales_data['Genre'].unique()
categories_list.index.name = 'category_id'
categories_list
# Out:
#             category_name
# category_id
# 0                  Sports
# 1                Platform
# 2                  Racing
# 3            Role-Playing
# 4                  Puzzle
# 5                    Misc
# 6                 Shooter
# 7              Simulation
# 8                  Action
# 9                Fighting
# 10              Adventure
# 11               Strategy

# %%
publishers_list = pd.DataFrame(columns=['publisher_name'])
publishers_list['publisher_name'] = game_sales_data['Publisher'].unique()
publishers_list.index.name = 'publisher_id'
publishers_list
# Out:
#                            publisher_name
# publisher_id
# 0                                Nintendo
# 1                  Microsoft Game Studios
# 2                    Take-Two Interactive
# 3             Sony Computer Entertainment
# 4                              Activision
# ...                                   ...
# 574                          Inti Creates
# 575                                Takuyo
# 576                    Interchannel-Holon
# 577                            Rain Games
# 578                     UIG Entertainment
#
# [579 rows x 1 columns]

# %%
games_list = game_sales_data[['Name', 'Platform', 'Year', 'Genre', 'Publisher']]

def map_name_to_id(name, column_name, names_list):
    result = names_list[names_list[column_name] == name].index.values.astype(int)
    if len(result) > 0:
        return result[0]
    else:
        return None
        
games_list.index.name = 'game_id'
games_list = games_list.rename(columns = {'Name':'game_name', 'Platform': 'platform_id', 'Year': 'year', 'Genre': 'category_id', 'Publisher': 'publisher_id'})
games_list['platform_id'] = games_list['platform_id'].map(lambda x: map_name_to_id(x, 'platform_name', platforms_list))
games_list['publisher_id'] = games_list['publisher_id'].map(lambda x: map_name_to_id(x, 'publisher_name', publishers_list))
games_list['category_id'] = games_list['category_id'].map(lambda x: map_name_to_id(x, 'category_name', categories_list))
games_list
# Out:
#                                                 game_name  platform_id  \
# game_id
# 1                                              Wii Sports            0
# 2                                       Super Mario Bros.            1
# 3                                          Mario Kart Wii            0
# 4                                       Wii Sports Resort            0
# 5                                Pokemon Red/Pokemon Blue            2
# ...                                                   ...          ...
# 16596                  Woody Woodpecker in Crazy Castle 5            8
# 16597                       Men in Black II: Alien Escape           18
# 16598    SCORE International Baja 1000: The Official Game            6
# 16599                                          Know How 2            3
# 16600                                    Spirits & Spells            8
#
#            year  category_id  publisher_id
# game_id
# 1        2006.0            0           0.0
# 2        1985.0            1           0.0
# 3        2008.0            2           0.0
# 4        2009.0            0           0.0
# 5        1996.0            3           0.0
# ...         ...          ...           ...
# 16596    2002.0            1         188.0
# 16597    2003.0            6          52.0
# 16598    2008.0            2           4.0
# 16599    2010.0            4         508.0
# 16600    2003.0            1         171.0
#
# [16598 rows x 5 columns]

# %%
sales_list = game_sales_data[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']]
sales_list
# Out:
#          NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# game_id
# 1           41.49     29.02      3.77         8.46         82.74
# 2           29.08      3.58      6.81         0.77         40.24
# 3           15.85     12.88      3.79         3.31         35.82
# 4           15.75     11.01      3.28         2.96         33.00
# 5           11.27      8.89     10.22         1.00         31.37
# ...           ...       ...       ...          ...           ...
# 16596        0.01      0.00      0.00         0.00          0.01
# 16597        0.01      0.00      0.00         0.00          0.01
# 16598        0.00      0.00      0.00         0.00          0.01
# 16599        0.00      0.01      0.00         0.00          0.01
# 16600        0.01      0.00      0.00         0.00          0.01
#
# [16598 rows x 5 columns]

# %%
platforms_list.to_sql('Platform', engine, if_exists='append')
categories_list.to_sql('Category', engine, if_exists='append')
publishers_list.to_sql('Publisher', engine, if_exists='append')
games_list.to_sql('Game', engine, if_exists='append')
sales_list.to_sql('Sales', engine, if_exists='append')

# %%
#initialize mapper operation
metadata = MetaData()

dic_table = {}
for table_name in engine.table_names():
    dic_table[table_name] = Table(table_name, metadata , autoload=True, autoload_with=engine)

# %%
mapper_stmt = select([dic_table['Platform'].columns.platform_id,dic_table['Platform'].columns.platform_name])
print('Mapper select: ')
print(mapper_stmt)
mapper_results = engine.execute(mapper_stmt).fetchall()
print(mapper_results)
print('\nNumber of platforms:', len(mapper_results))
# Out:
# Mapper select:
# SELECT "Platform".platform_id, "Platform".platform_name
# FROM "Platform"
# [(0, 'Wii'), (1, 'NES'), (2, 'GB'), (3, 'DS'), (4, 'X360'), (5, 'PS3'), (6, 'PS2'), (7, 'SNES'), (8, 'GBA'), (9, '3DS'), (10, 'PS4'), (11, 'N64'), (12, 'PS'), (13, 'XB'), (14, 'PC'), (15, '2600'), (16, 'PSP'), (17, 'XOne'), (18, 'GC'), (19, 'WiiU'), (20, 'GEN'), (21, 'DC'), (22, 'PSV'), (23, 'SAT'), (24, 'SCD'), (25, 'WS'), (26, 'NG'), (27, 'TG16'), (28, '3DO'), (29, 'GG'), (30, 'PCFX')]
#
# Number of platforms: 31

# %%
# all Wii games
mapper_stmt = select([dic_table['Game'].columns.game_name]).\
    where(dic_table['Game'].columns.platform_id.in_(select([dic_table['Platform'].columns.platform_id]).\
         where(dic_table['Platform'].columns.platform_name == 'Wii')))
print('Mapper select: ')
print(mapper_stmt)
mapper_results = engine.execute(mapper_stmt).fetchall()
print(mapper_results)
# Out:
# Mapper select:
# SELECT "Game".game_name
# FROM "Game"
# WHERE "Game".platform_id IN (SELECT "Platform".platform_id
# FROM "Platform"
# WHERE "Platform".platform_name = :platform_name_1)
# [('Wii Sports',), ('Mario Kart Wii',), ('Wii Sports Resort',), ('Wii Play',), ('New Super Mario Bros. Wii',), ('Wii Fit',), ('Wii Fit Plus',), ('Super Smash Bros. Brawl',), ('Super Mario Galaxy',), ('Just Dance 3',), ('Just Dance 2',), ('Wii Party',), ('Mario Party 8',), ('Mario & Sonic at the Olympic Games',), ('Super Mario Galaxy 2',), ('The Legend of Zelda: Twilight Princess',), ('Just Dance',), ('Just Dance 4',), ('Zumba Fitness',), ('Donkey Kong Country Returns',), ('LEGO Star Wars: The Complete Saga',), ("Link's Crossbow Training",), ('Animal Crossing: City Folk',), ('Guitar Hero III: Legends of Rock',), ('Mario & Sonic at the Olympic Winter Games',), ('Michael Jackson: The Experience',), ('The Legend of Zelda: Skyward Sword',), ('Carnival Games',), ('EA Sports Active',), ('Big Brain Academy: Wii Degree',), ('Mario & Sonic at the London 2012 Olympic Games',), ('Just Dance 2014',), ('Super Paper Mario',), ('Guitar Hero: World Tour',), ('Mario Party 9',), ('Wii Music',), ('LEGO Batman: The Videogame',), ('Epic Mickey',), ('WarioWare: Smooth Moves',), ('Cooking Mama: Cook Off',), ('Zumba Fitness 2',), ("Skylanders: Spyro's Adventure",), ('Sonic and the Secret Rings',), ('Skylanders Giants',), ('Mario Strikers Charged',), ('Super Mario All-Stars: Limited Edition',), ('Deca Sports',), ('Game Party',), ('LEGO Harry Potter: Years 1-4',), ('uDraw Studio',), ('LEGO Indiana Jones: The Original Adventures',), ('Skylanders SWAP Force',), ('My Fitness Coach',), ('Just Dance Kids',), ('Just Dance 2015',), ('Super Monkey Ball: Banana Blitz',), ('Call of Duty 3',), ('Resident Evil 4',), ('Monster Hunter Tri',), ('Sonic Unleashed',), ('Your Shape featuring Jenny McCarthy',), ("Kirby's Epic Yarn",), ('Mario Sports Mix',), ('Rock Band',), ('Wipeout: The Game',), ('Dance Dance Revolution: Hottest Party',), ('Rayman Raving Rabbids: TV Party',), ('Call of Duty: World at War',), ('Mario Super Sluggers',), ('Monopoly',), ('Toy Story Mania!',), ('Star Wars: The Force Unleashed',), ('Game Party 2',), ('LEGO Star Wars III: The Clone Wars',), ('GoldenEye 007 (2010)',), ('Rayman Raving Rabbids 2',), ('Metroid Prime 3: Corruption',), ('High School Musical: Sing It!',), ('The Beatles: Rock Band',), ('Sonic Colors',), ('Disney Infinity',), ('Game Party 3',), ("Cabela's Big Game Hunter 2010",), ('We Ski',), ("Kirby's Return to Dreamland",), ('Star Wars The Clone Wars: Lightsaber Duels',), ('MySims',), ('Shaun White Snowboarding: Road Trip',), ('Big Beach Sports',), ('Go Vacation',), ('LEGO Pirates of the Caribbean: The Video Game',), ('Pokemon Battle Revolution',), ('Dance Dance Revolution: Hottest Party 2',), ('Carnival Games: Mini Golf',), ('Guitar Hero 5',), ('Active Life: Outdoor Challenge',), ('Resident Evil: The Umbrella Chronicles',), ('MySims Kingdom',), ('Call of Duty: Modern Warfare: Reflex Edition',), ('Sonic & Sega All-Stars Racing',), ('Disney Sing It: Pop Hits',), ('The Sims 3',), ('New Play Control! Mario Power Tennis',), ('The House of the Dead 2 & 3 Return',), ('LEGO Batman 2: DC Super Heroes',), ('Smarty Pants',), ('Hasbro Family Game Night',), ('Rayman Raving Rabbids',), ('LEGO Indiana Jones 2: The Adventure Continues',), ('Tiger Woods PGA Tour 09 All-Play',), ('Toy Story 3: The Video Game',), ('Metroid: Other M',), ('Call of Duty: Black Ops',), ('Hannah Montana: Spotlight World Tour',), ('Hasbro Family Game Night 2',), ('Disney Princess: Enchanted Journey',), ('LEGO Harry Potter: Years 5-7',), ('Deal or No Deal',), ('High School Musical 3: Senior Year DANCE!',), ("Gold's Gym: Cardio Workout",), ('EA Playground',), ('EA Sports Active 2',), ('Need for Speed Carbon',), ('Guitar Hero: Aerosmith',), ("Jillian Michaels' Fitness Ultimatum 2009",), ('Rockstar Games presents Table Tennis',), ('Winter Sports: The Ultimate Challenge',), ('Ben 10: Protector of Earth',), ('Boom Blox',), ('The Sims 2: Castaway',), ('Just Dance 2016',), ('Disney Sing It',), ("PokéPark Wii: Pikachu's Adventure",), ('Pro Evolution Soccer 2008',), ('Wario Land: Shake  ...

# %%
# 10 Best selling games
mapper_stmt = select([dic_table['Game'].columns.game_name, dic_table["Sales"].columns.Global_Sales]).\
    where(dic_table['Game'].columns.game_id == dic_table["Sales"].columns.game_id).\
    order_by(dic_table["Sales"].columns.game_id).limit(10)
print('Mapper select: ')
print(mapper_stmt)
mapper_results = engine.execute(mapper_stmt).fetchall()
print(mapper_results)
# Out:
# Mapper select:
# SELECT "Game".game_name, "Sales"."Global_Sales"
# FROM "Game", "Sales"
# WHERE "Game".game_id = "Sales".game_id ORDER BY "Sales".game_id
#  LIMIT :param_1
# [('Wii Sports', 82.74), ('Super Mario Bros.', 40.24), ('Mario Kart Wii', 35.82), ('Wii Sports Resort', 33.0), ('Pokemon Red/Pokemon Blue', 31.37), ('Tetris', 30.26), ('New Super Mario Bros.', 30.01), ('Wii Play', 29.02), ('New Super Mario Bros. Wii', 28.62), ('Duck Hunt', 28.31)]

# %%
# 10 Worst selling games
mapper_stmt = select([dic_table['Game'].columns.game_name, dic_table["Sales"].columns.Global_Sales]).\
    where(dic_table['Game'].columns.game_id == dic_table["Sales"].columns.game_id).\
    order_by(dic_table["Sales"].columns.game_id.desc()).limit(10)
print('Mapper select: ')
print(mapper_stmt)
mapper_results = engine.execute(mapper_stmt).fetchall()
print(mapper_results)
# Out:
# Mapper select:
# SELECT "Game".game_name, "Sales"."Global_Sales"
# FROM "Game", "Sales"
# WHERE "Game".game_id = "Sales".game_id ORDER BY "Sales".game_id DESC
#  LIMIT :param_1
# [('Spirits & Spells', 0.01), ('Know How 2', 0.01), ('SCORE International Baja 1000: The Official Game', 0.01), ('Men in Black II: Alien Escape', 0.01), ('Woody Woodpecker in Crazy Castle 5', 0.01), ('Plushees', 0.01), ('Myst IV: Revelation', 0.01), ('Eiyuu Densetsu: Sora no Kiseki Material Collection Portable', 0.01), ('Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirube Kareru', 0.01), ('Mega Brain Boost', 0.01)]

# %%
#function finding all games for given platform
mapper_stmt = '''CREATE OR REPLACE FUNCTION get_games_for_plat(plat_name VARCHAR)\
RETURNS TABLE (game_name VARCHAR) AS $$ \
BEGIN RETURN QUERY SELECT "Game".game_name FROM "Game" INNER JOIN "Platform" on "Game".platform_id="Platform".platform_id \
WHERE "Platform".platform_name = plat_name;\
END;$$ \
LANGUAGE 'plpgsql';'''

print(mapper_stmt)
mapper_results = engine.execute(mapper_stmt)
# Out:
# CREATE OR REPLACE FUNCTION get_games_for_plat(plat_name VARCHAR)RETURNS TABLE (game_name VARCHAR) AS $$ BEGIN RETURN QUERY SELECT "Game".game_name FROM "Game" INNER JOIN "Platform" on "Game".platform_id="Platform".platform_id WHERE "Platform".platform_name = plat_name;END;$$ LANGUAGE 'plpgsql';

# %%
mapper_stmt = "Select * from get_games_for_plat('PC')" 
print(mapper_stmt)
mapper_results = engine.execute(mapper_stmt).fetchall()
print(mapper_results)
# Out:
# Select * from get_games_for_plat('PC')
# [('The Sims 3',), ('World of Warcraft',), ('Diablo III',), ('Microsoft Flight Simulator',), ('StarCraft II: Wings of Liberty',), ('Warcraft II: Tides of Darkness',), ('Half-Life',), ('World of Warcraft: The Burning Crusade',), ('The Elder Scrolls V: Skyrim',), ('The Sims: Unleashed',), ('Doom II: Hell on Earth',), ('The Sims: Vacation',), ('The Sims: Livin Large',), ('The Sims 4',), ('Star Wars: The Old Republic',), ('Command & Conquer: Red Alert',), ('Myst',), ('Battlefield 3',), ('Riven: The Sequel to Myst',), ('Theme Hospital',), ('Monopoly',), ('Half-Life 2',), ('Guild Wars 2',), ('Tomb Raider II',), ('The Sims: House Party',), ('SimCity 2000',), ('World of Warcraft: Cataclysm',), ('Sim Theme Park',), ('Warcraft: Orcs & Humans',), ('Star Wars: Dark Forces',), ('Who wants to be a millionaire',), ("The Sims: Makin' Magic",), ('World of Warcraft: Mists of Pandaria',), ('The Sims: Hot Date',), ('Call of Duty: Modern Warfare 3',), ('The Sims 3: Late Night Expansion Pack',), ("Sid Meier's Civilization V",), ('The Sims: Superstar',), ('StarCraft II: Heart of the Swarm',), ('Call of Duty: Black Ops',), ('Diablo',), ('Command & Conquer: Tiberian Sun',), ('Warcraft III: The Frozen Throne',), ('Call of Duty: Black Ops II',), ('Football Manager 2012',), ('Final Fantasy XIV: A Realm Reborn',), ('Anno 2070',), ('SimCity (2013)',), ('Battlefield 4',), ('Command & Conquer: Red Alert 2',), ('World of Warcraft: Wrath of the Lich King',), ('The Sims 2: Nightlife',), ('Football Manager 2011',), ('Championship Manager 03/04',), ('RollerCoaster Tycoon 2',), ('Farming Simulator 2015',), ('Fallout 4',), ('Spore',), ('Football Manager 2013',), ('Fallout: New Vegas',), ('Worldwide Soccer Manager 2009',), ('Call of Duty 4: Modern Warfare',), ('Worldwide Soccer Manager 2008',), ('Empire: Total War',), ('Grand Theft Auto V',), ('Championship Manager 99/00',), ('Diablo II: Lord of Destruction',), ('Tomb Raider',), ('Championship Manager 3',), ('Farming Simulator 2013',), ('Fallout 3',), ('Far Cry 3',), ('Grand Theft Auto: San Andreas',), ('Mass Effect 3',), ('The Witcher 2: Assassins of Kings',), ("Assassin's Creed III",), ('Borderlands 2',), ("Assassin's Creed",), ('The Elder Scrolls Online',), ('Call of Duty: Modern Warfare 2',), ('Grand Theft Auto IV',), ('The 7th Guest',), ('Portal 2',), ("Assassin's Creed: Revelations",), ('Total War: Rome II',), ('Crysis 2',), ('Call of Duty: Ghosts',), ('Dragon Age: Inquisition',), ('XCOM: Enemy Unknown',), ('Crysis',), ('Battlefield: Bad Company 2',), ('Football Manager 2014',), ("Assassin's Creed IV: Black Flag",), ('The Sims: Medieval',), ('Mass Effect',), ('The Witcher 3: Wild Hunt',), ('RIFT',), ('BioShock Infinite',), ('Command & Conquer: Red Alert 3',), ('The Sims 3: High-End Loft Stuff',), ('Rocksmith 2014',), ('Napoleon: Total War',), ('Crysis 3',), ('Dragon Age II',), ('The Sims 3: Generations',), ('Far Cry 4',), ('Tomb Raider III: Adventures of Lara Croft',), ('Dead Space',), ("Assassin's Creed: Brotherhood",), ('Total War: Shogun 2',), ('Deus Ex: Human Revolution',), ('The Sims 3: World Adventures',), ('Titanfall',), ("Assassin's Creed II",), ("Assassin's Creed: Unity",), ('Star Wars Battlefront (2015)',), ('Batman: Arkham City',), ('The Sims 2: Open for Business',), ('Dragon Age: Origins',), ('StarCraft II: Legacy of the Void',), ('Euro Truck Simulator',), ('Dishonored',), ('Medal of Honor',), ('Sniper: Art of Victory',), ('Far Cry 2',), ('World of Warcraft: Warlords of Draenor',), ('Football Manager 2015',), ('Warhammer 40,000: Dawn of War II',), ('The Sims 3: Ambitions',), ('FIFA 12',), ('The Sims 3: Outdoor Living Stuff',), ('Wolfenstein: The New Order',), ('Watch Dogs',), ('FIFA 14',), ('Overwatch',), ('Max Payne 3',), ('Microsoft Flight Simulator X',), ('TERA',), ('Tomb Raider: The Last Revelation',), ('BioShock',), ('Call of Duty: Advanced Warfare',), ('Duke Nukem Forever',), ('FIFA Soccer 13',), ('Mafia II',), ('Mass Effect 2',), ('Age of Empires III',), ('Dawn of Discovery',), ('Saints Row:  ...

# %%
#function finding all games of given category
mapper_stmt = '''CREATE OR REPLACE FUNCTION get_games_for_cat(cat_name VARCHAR)\
RETURNS TABLE (game_name VARCHAR) AS $$ \
BEGIN RETURN QUERY SELECT "Game".game_name FROM "Game" INNER JOIN "Category" on "Game".category_id="Category".category_id \
WHERE "Category".category_name = cat_name;\
END;$$ \
LANGUAGE 'plpgsql';'''

print(mapper_stmt)
mapper_results = engine.execute(mapper_stmt)
# Out:
# CREATE OR REPLACE FUNCTION get_games_for_cat(cat_name VARCHAR)RETURNS TABLE (game_name VARCHAR) AS $$ BEGIN RETURN QUERY SELECT "Game".game_name FROM "Game" INNER JOIN "Category" on "Game".category_id="Category".category_id WHERE "Category".category_name = cat_name;END;$$ LANGUAGE 'plpgsql';

# %%
mapper_stmt = "Select * from get_games_for_cat('Shooter')" 
print(mapper_stmt)
mapper_results = engine.execute(mapper_stmt).fetchall()
print(mapper_results)
# Out:
# Select * from get_games_for_cat('Shooter')
# [('Duck Hunt',), ('Call of Duty: Modern Warfare 3',), ('Call of Duty: Black Ops',), ('Call of Duty: Black Ops 3',), ('Call of Duty: Black Ops II',), ('Call of Duty: Black Ops II',), ('Call of Duty: Modern Warfare 2',), ('Call of Duty: Modern Warfare 3',), ('Call of Duty: Black Ops',), ('Halo 3',), ('Call of Duty: Modern Warfare 2',), ('Call of Duty: Ghosts',), ('Halo: Reach',), ('Halo 4',), ('Call of Duty: Ghosts',), ('Call of Duty 4: Modern Warfare',), ('Halo 2',), ('GoldenEye 007',), ('Star Wars Battlefront (2015)',), ('Call of Duty: Advanced Warfare',), ('Call of Duty: World at War',), ('Battlefield 3',), ('Call of Duty: Black Ops 3',), ('Battlefield 3',), ('Medal of Honor: Frontline',), ('Gears of War 2',), ('Call of Duty 4: Modern Warfare',), ('Halo: Combat Evolved',), ('Halo 3: ODST',), ('Gears of War 3',), ('Gears of War',), ('Destiny',), ('Call of Duty: World at War',), ('Medal of Honor: Rising Sun',), ('Call of Duty: Advanced Warfare',), ("Link's Crossbow Training",), ('Splatoon',), ('Call of Duty: Advanced Warfare',), ('Resistance: Fall of Man',), ('Call of Duty: Advanced Warfare',), ('Asteroids',), ('Halo 5: Guardians',), ("Uncharted 4: A Thief's End",), ('Half-Life',), ('Far Cry 4',), ('Star Fox 64',), ('Left 4 Dead 2',), ('Battlefield 4',), ('SOCOM: U.S. Navy SEALs',), ('Call of Duty: Ghosts',), ("Tom Clancy's The Division",), ('Star Wars: Battlefront',), ('Doom II: Hell on Earth',), ('Star Wars: Battlefront II',), ('James Bond 007: Agent Under Fire',), ('Battlefield 4',), ('Left 4 Dead',), ('Star Wars Battlefront (2015)',), ('Battlefield: Bad Company 2',), ('Far Cry 3',), ('Borderlands',), ('Battlefield 4',), ('James Bond 007: Nightfire',), ('Max Payne',), ('Destiny',), ('007: Tomorrow Never Dies',), ('Resident Evil 6',), ('Halo: The Master Chief Collection',), ('Borderlands 2',), ('Far Cry 3',), ('Killzone 2',), ('Gears of War: Ultimate Edition',), ('Star Fox',), ('Battlefield: Bad Company 2',), ('SOCOM II: U.S. Navy SEALs',), ('Titanfall',), ('Call of Duty: Finest Hour',), ('Syphon Filter',), ('Call of Duty: Ghosts',), ('BioShock',), ('Medal of Honor',), ('Metroid Prime',), ('Killzone 3',), ('Battlefield 3',), ('Missile Command',), ('Call of Duty 3',), ('Call Of Duty 2: Big Red One',), ('Medal of Honor',), ('Medal of Honor Heroes',), ('Medal of Honor',), ('Killzone: Shadow Fall',), ('Space Invaders',), ('Resistance 2',), ('Halo: Combat Evolved Anniversary',), ("Tom Clancy's Rainbow Six: Vegas 2",), ('Half-Life 2',), ('James Bond 007: Everything or Nothing',), ('Borderlands 2',), ('Call of Duty 3',), ('BioShock 2',), ('Syphon Filter 2',), ("Tom Clancy's Rainbow Six: Siege",), ('Call of Duty: Roads to Victory',), ('Demon Attack',), ('Borderlands',), ('Portal 2',), ('Battlefield: Hardline',), ('Spec Ops: Airborne Commando',), ('SOCOM: U.S. Navy SEALs: Combined Assault',), ('Call of Duty 2',), ("Tom Clancy's The Division",), ('Battlefield 4',), ('Resident Evil 6',), ('Call of Duty: World at War',), ('BioShock Infinite',), ("Tom Clancy's Rainbow Six: Vegas",), ('Destiny',), ('Star Wars: Dark Forces',), ("Tom Clancy's Ghost Recon",), ('Red Faction',), ('Destiny: The Taken King',), ('Max Payne 3',), ('Medal of Honor: European Assault (All Region sales)',), ('The Orange Box',), ('Metroid Prime 3: Corruption',), ('Call of Duty: Black Ops 3',), ("Tom Clancy's Ghost Recon",), ('BioShock Infinite',), ('Call of Duty: Black Ops 3',), ('Star Wars: Battlefront',), ('Crackdown',), ('Portal 2',), ('Uncharted: Golden Abyss',), ('Destiny',), ('Overwatch',), ('The Order: 1886',), ('Call of Duty: World at War Final Fronts',), ('Call of Duty: Modern Warfare 3',), ('SOCOM 3: U.S. Navy SEALs',), ('Star Wars Battlefront: Renegade Squadron',), ('Time Crisis',), ('Star Wars: Battlefront II',), ('Max Payne 3',), ('Super Scope 6',), ('Army of Two',), ("Tom Clancy's Rainbow Six",), ('Call of Duty: Black Ops',), ('Rage',), ('Gears of War: Judgment',), ('Far Cry 4',), ('River Raid',), ('Wolfenstein: The New Order',), ('Conflict: Desert Storm', ...

# %%
mapper_stmt = "Select * from get_games_for_cat('Role-Playing')" 
print(mapper_stmt)
mapper_results = engine.execute(mapper_stmt).fetchall()
print(mapper_results)
# Out:
# Select * from get_games_for_cat('Role-Playing')
# [('Pokemon Red/Pokemon Blue',), ('Pokemon Gold/Pokemon Silver',), ('Pokemon Diamond/Pokemon Pearl',), ('Pokemon Ruby/Pokemon Sapphire',), ('Pokemon Black/Pokemon White',), ('Pokémon Yellow: Special Pikachu Edition',), ('Pokemon X/Pokemon Y',), ('Pokemon Omega Ruby/Pokemon Alpha Sapphire',), ('Pokemon FireRed/Pokemon LeafGreen',), ('Final Fantasy VII',), ('The Elder Scrolls V: Skyrim',), ('Pokemon Black 2/Pokemon White 2',), ('Final Fantasy X',), ('Final Fantasy VIII',), ('Pokémon Platinum Version',), ('Fallout 4',), ('The Elder Scrolls V: Skyrim',), ('Pokémon Emerald Version',), ('Kingdom Hearts',), ('Pokémon Crystal Version',), ('World of Warcraft',), ('Final Fantasy XII',), ('Dragon Quest IX: Sentinels of the Starry Skies',), ('Monster Hunter Freedom Unite',), ('Final Fantasy XIII',), ('Final Fantasy IX',), ('Final Fantasy X-2',), ('Dragon Quest VIII: Journey of the Cursed King',), ('Diablo III',), ('Fable III',), ('Fallout 3',), ('Pokemon Mystery Dungeon: Explorers of Time/Explorers of Darkness',), ('Monster Hunter Freedom 3',), ('Dragon Quest VII: Warriors of Eden',), ('The Elder Scrolls IV: Oblivion',), ('Kingdom Hearts II',), ('Fable II',), ('Fallout 4',), ('World of Warcraft: The Burning Crusade',), ('Fallout: New Vegas',), ('Fallout 3',), ('Monster Hunter 4 Ultimate',), ('The Elder Scrolls V: Skyrim',), ('Dragon Warrior III',), ("Mario & Luigi: Bowser's Inside Story",), ('The Witcher 3: Wild Hunt',), ('Monster Hunter 4',), ('Final Fantasy III',), ('Yokai Watch 2 Ganso/Honke',), ('Crisis Core: Final Fantasy VII',), ('Dragon Quest VI: Maboroshi no Daichi',), ('Fallout: New Vegas',), ('The Elder Scrolls IV: Oblivion',), ('Dragon Warrior IV',), ('Mass Effect 2',), ('Mass Effect 3',), ('Star Wars: The Old Republic',), ('Mass Effect',), ('The Elder Scrolls III: Morrowind',), ('Dragon Quest V: Tenkuu no Hanayome',), ('Monster Hunter Tri',), ('Yokai Watch 2 Shinuchi',), ('Final Fantasy XIII-2',), ('Fable',), ('Monster Hunter Freedom 2',), ('Dragon Age: Origins',), ('Dragon Warrior II',), ('Pokémon Colosseum',), ('Dragon Warrior',), ('Marvel: Ultimate Alliance',), ('Final Fantasy V',), ('Final Fantasy Tactics',), ('Dragon Warrior Monsters',), ('Chrono Trigger',), ('Pokemon Ranger: Shadows of Almia',), ('Paper Mario: Sticker Star',), ('Paper Mario: The Thousand-Year Door',), ('Monster Hunter Tri',), ('Star Wars: Knights of the Old Republic',), ('Yu-Gi-Oh: Duel Monsters 4',), ('Pokemon Ranger',), ('Mario & Luigi: Superstar Saga',), ('Final Fantasy XIII',), ('Super Mario RPG: Legend of the Seven Stars',), ('Final Fantasy Tactics Advance',), ('Final Fantasy III',), ('Parasite Eve',), ('World of Warcraft: Cataclysm',), ('Kingdom Hearts: Birth by Sleep',), ('Dark Souls',), ('Pokemon Mystery Dungeon: Red/Blue Rescue Team',), ('Mario & Luigi: Dream Team',), ('Pokémon Mystery Dungeon: Blue Rescue Team',), ('Diablo III',), ('Kingdom Hearts 358/2 Days',), ('Fire Emblem: Awakening',), ('Dragon Age: Inquisition',), ('X-Men Legends',), ('Yokai Watch',), ('Yu-Gi-Oh! Forbidden Memories',), ('The Legend of Dragoon',), ('Chrono Cross',), ('Kingdom Hearts: Chain of Memories',), ("Demon's Souls",), ('World of Warcraft: Mists of Pandaria',), ('Secret of Mana',), ('Dragon Quest VI: Realms of Revelation',), ('Dragon Quest Monsters: Joker',), ("Dragon's Dogma",), ('Final Fantasy II',), ('Golden Sun',), ('Kingdom Hearts',), ('Xenosaga Episode I: Der Wille zur Macht',), ('Diablo III',), ('The Elder Scrolls Online',), ('Star Ocean: Till The End of Time',), ('Dragon Age: Origins',), ('Dragon Ball Z: The Legacy of Goku',), ('Dragon Quest V: Tenkuu no Hanayome',), ('Dragon Quest IV: Chapters of the Chosen',), ('Pokemon Battle Revolution',), ('Dragon Quest V: Hand of the Heavenly Bride',), ('Diablo',), ('Pokemon Mystery Dungeon: Explorers of Sky',), ('Dark Souls III',), ('Dragon Quest Monsters 2',), ('Ni no Kuni: Wrath of the White Witch',), ('Fire Emblem Fates',), ('Dark Cloud',), ('Puzzle & Dragons',), ('Final Fantasy XIV: A Realm Reborn',), ('Final Fantas ...
